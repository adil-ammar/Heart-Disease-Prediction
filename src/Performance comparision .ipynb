# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
Train_Test_Ratio = ['60/40', '65/35', '70/30', '75/25']

Accuracy = [88.9, 89.32 , 89.70, 91.36]
Accuracy_scratch = [76.22, 78.5, 79.0, 82.57]
precision = [88, 89, 90, 92]
precision_scratch = [75.2, 79.1, 82.5, 83]
  
plt.plot(Train_Test_Ratio, Accuracy_scratch)
plt.title(' vs Accuracy')
plt.xlabel('Train/Test Ratio')
plt.ylabel('Precision %')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
max_depth = ['5', '10', '15', '20', '25']
Accuracy_scratch = [72, 78, 80.5, 83, 83]
precision_scratch = []
plt.plot(max_depth, Accuracy_scratch)
plt.title('max_depth vs Accuracy')
plt.xlabel('max_depth')
plt.ylabel('Accuracy %')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i,y[i],y[i])

# %%
method = ['Logistic Reg', 'Naive Bayes', 'KNN', 'SVM', 'Decision Trees']
accuracy = [81.58, 86.9, 88, 72.4, 83]
precision = [83.33, 94.4, 91.1, 70.3, 83.4]
plt.title('Precision comparison for different techniques used')
plt.xlabel('Technique')
plt.ylabel('Precision %')
addlabels(method, precision)
plt.bar(method, precision)
# Out:
# <BarContainer object of 5 artists>
