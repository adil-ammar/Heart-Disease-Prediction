# %%
import pandas as pd
from sklearn import svm
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
data = pd.read_csv('../data/heart_disease_dataset_UCI.csv')
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
#Normalizing data
# standardScalar = StandardScaler()
# normalizing_columns = ['age','trestbps','chol','thalach','oldpeak']
# data[normalizing_columns] = standardScalar.fit_transform(data[normalizing_columns])

# %%
data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
#Dividing into input and output
x= data.drop(['target'], axis=1)
y= data['target']

# %%
x
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal
# 0        0   0     1
# 1        0   0     2
# 2        2   0     2
# 3        2   0     2
# 4        2   0     2
# ..     ...  ..   ...
# 298      1   0     3
# 299      1   0     3
# 300      1   2     3
# 301      1   1     3
# 302      1   1     2
#
# [303 rows x 13 columns]

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 298    0
# 299    0
# 300    0
# 301    0
# 302    0
# Name: target, Length: 303, dtype: int64

# %%
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size=0.25, random_state=40)

# %%
for k in ['linear', 'poly', 'sigmoid']:
    for c in [0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000]:
        print("C: " + str(c))
        classifier = svm.SVC(kernel=k, C=c)
        classifier.fit(x_train, y_train)
        predict = classifier.predict(x_test)
        SVM_classifier_cm = confusion_matrix(y_test, predict)
        print("ConfusionMatrix (" + k + " kernel) : " + str(SVM_classifier_cm))
        print("Accuracy (" + k + " kernel) : " + str(accuracy_score(y_test, predict)))
    print("=================================================================")
# Out:
# C: 0.0001
# ConfusionMatrix (linear kernel) : [[19 15]
#  [ 8 34]]
# Accuracy (linear kernel) : 0.6973684210526315
# C: 0.001
# ConfusionMatrix (linear kernel) : [[19 15]
#  [ 8 34]]
# Accuracy (linear kernel) : 0.6973684210526315
# C: 0.01
# ConfusionMatrix (linear kernel) : [[23 11]
#  [ 2 40]]
# Accuracy (linear kernel) : 0.8289473684210527
# C: 0.1
# ConfusionMatrix (linear kernel) : [[28  6]
#  [ 3 39]]
# Accuracy (linear kernel) : 0.881578947368421
# C: 1
# ConfusionMatrix (linear kernel) : [[29  5]
#  [ 4 38]]
# Accuracy (linear kernel) : 0.881578947368421
# C: 10
# ConfusionMatrix (linear kernel) : [[29  5]
#  [ 5 37]]
# Accuracy (linear kernel) : 0.868421052631579
# C: 100
# ConfusionMatrix (linear kernel) : [[28  6]
#  [ 3 39]]
# Accuracy (linear kernel) : 0.881578947368421
# C: 1000
# ConfusionMatrix (linear kernel) : [[28  6]
#  [ 3 39]]
# Accuracy (linear kernel) : 0.881578947368421
# =================================================================
# C: 0.0001
# ConfusionMatrix (poly kernel) : [[ 0 34]
#  [ 0 42]]
# Accuracy (poly kernel) : 0.5526315789473685
# C: 0.001
# ConfusionMatrix (poly kernel) : [[ 0 34]
#  [ 0 42]]
# Accuracy (poly kernel) : 0.5526315789473685
# C: 0.01
# ConfusionMatrix (poly kernel) : [[ 0 34]
#  [ 0 42]]
# Accuracy (poly kernel) : 0.5526315789473685
# C: 0.1
# ConfusionMatrix (poly kernel) : [[ 0 34]
#  [ 0 42]]
# Accuracy (poly kernel) : 0.5526315789473685
# C: 1
# ConfusionMatrix (poly kernel) : [[18 16]
#  [ 8 34]]
# Accuracy (poly kernel) : 0.6842105263157895
# C: 10
# ConfusionMatrix (poly kernel) : [[19 15]
#  [ 9 33]]
# Accuracy (poly kernel) : 0.6842105263157895
# C: 100
# ConfusionMatrix (poly kernel) : [[22 12]
#  [ 3 39]]
# Accuracy (poly kernel) : 0.8026315789473685
# C: 1000
# ConfusionMatrix (poly kernel) : [[27  7]
#  [ 3 39]]
# Accuracy (poly kernel) : 0.868421052631579
# =================================================================
# C: 0.0001
# ConfusionMatrix (sigmoid kernel) : [[ 0 34]
#  [ 0 42]]
# Accuracy (sigmoid kernel) : 0.5526315789473685
# C: 0.001
# ConfusionMatrix (sigmoid kernel) : [[ 0 34]
#  [ 0 42]]
# Accuracy (sigmoid kernel) : 0.5526315789473685
# C: 0.01
# ConfusionMatrix (sigmoid kernel) : [[ 0 34]
#  [ 0 42]]
# Accuracy (sigmoid kernel) : 0.5526315789473685
# C: 0.1
# ConfusionMatrix (sigmoid kernel) : [[ 0 34]
#  [ 0 42]]
# Accuracy (sigmoid kernel) : 0.5526315789473685
# C: 1
# ConfusionMatrix (sigmoid kernel) : [[ 0 34]
#  [ 0 42]]
# Accuracy (sigmoid kernel) : 0.5526315789473685
# C: 10
# ConfusionMatrix (sigmoid kernel) : [[16 18]
#  [18 24]]
# Accuracy (sigmoid kernel) : 0.5263157894736842
# C: 100
# ConfusionMatrix (sigmoid kernel) : [[15 19]
#  [18 24]]
# Accuracy (sigmoid kernel) : 0.5131578947368421
# C: 1000
# ConfusionMatrix (sigmoid kernel) : [[15 19]
#  [18 24]]
# Accuracy (sigmoid kernel) : 0.5131578947368421
# =================================================================

# %%
for c in [0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000]:
    for g in [0.001, 0.01, 0.1, 1, 10, 100]:
        print("C: " + str(c))
        print("G: " + str(g))
        classifier = svm.SVC(kernel='rbf', C=c, gamma=g)
        classifier.fit(x_train, y_train)
        predict = classifier.predict(x_test)
        SVM_classifier_cm = confusion_matrix(y_test, predict)
        print("ConfusionMatrix (" + k + " kernel) : " + str(SVM_classifier_cm))
        print("Accuracy (" + k + " kernel) : " + str(accuracy_score(y_test, predict)))
# Out:
# C: 0.0001
# G: 0.001
# ConfusionMatrix (sigmoid kernel) : [[ 0 34]
#  [ 0 42]]
# Accuracy (sigmoid kernel) : 0.5526315789473685
# C: 0.0001
# G: 0.01
# ConfusionMatrix (sigmoid kernel) : [[ 0 34]
#  [ 0 42]]
# Accuracy (sigmoid kernel) : 0.5526315789473685
# C: 0.0001
# G: 0.1
# ConfusionMatrix (sigmoid kernel) : [[ 0 34]
#  [ 0 42]]
# Accuracy (sigmoid kernel) : 0.5526315789473685
# C: 0.0001
# G: 1
# ConfusionMatrix (sigmoid kernel) : [[ 0 34]
#  [ 0 42]]
# Accuracy (sigmoid kernel) : 0.5526315789473685
# C: 0.0001
# G: 10
# ConfusionMatrix (sigmoid kernel) : [[ 0 34]
#  [ 0 42]]
# Accuracy (sigmoid kernel) : 0.5526315789473685
# C: 0.0001
# G: 100
# ConfusionMatrix (sigmoid kernel) : [[ 0 34]
#  [ 0 42]]
# Accuracy (sigmoid kernel) : 0.5526315789473685
# C: 0.001
# G: 0.001
# ConfusionMatrix (sigmoid kernel) : [[ 0 34]
#  [ 0 42]]
# Accuracy (sigmoid kernel) : 0.5526315789473685
# C: 0.001
# G: 0.01
# ConfusionMatrix (sigmoid kernel) : [[ 0 34]
#  [ 0 42]]
# Accuracy (sigmoid kernel) : 0.5526315789473685
# C: 0.001
# G: 0.1
# ConfusionMatrix (sigmoid kernel) : [[ 0 34]
#  [ 0 42]]
# Accuracy (sigmoid kernel) : 0.5526315789473685
# C: 0.001
# G: 1
# ConfusionMatrix (sigmoid kernel) : [[ 0 34]
#  [ 0 42]]
# Accuracy (sigmoid kernel) : 0.5526315789473685
# C: 0.001
# G: 10
# ConfusionMatrix (sigmoid kernel) : [[ 0 34]
#  [ 0 42]]
# Accuracy (sigmoid kernel) : 0.5526315789473685
# C: 0.001
# G: 100
# ConfusionMatrix (sigmoid kernel) : [[ 0 34]
#  [ 0 42]]
# Accuracy (sigmoid kernel) : 0.5526315789473685
# C: 0.01
# G: 0.001
# ConfusionMatrix (sigmoid kernel) : [[ 0 34]
#  [ 0 42]]
# Accuracy (sigmoid kernel) : 0.5526315789473685
# C: 0.01
# G: 0.01
# ConfusionMatrix (sigmoid kernel) : [[ 0 34]
#  [ 0 42]]
# Accuracy (sigmoid kernel) : 0.5526315789473685
# C: 0.01
# G: 0.1
# ConfusionMatrix (sigmoid kernel) : [[ 0 34]
#  [ 0 42]]
# Accuracy (sigmoid kernel) : 0.5526315789473685
# C: 0.01
# G: 1
# ConfusionMatrix (sigmoid kernel) : [[ 0 34]
#  [ 0 42]]
# Accuracy (sigmoid kernel) : 0.5526315789473685
# C: 0.01
# G: 10
# ConfusionMatrix (sigmoid kernel) : [[ 0 34]
#  [ 0 42]]
# Accuracy (sigmoid kernel) : 0.5526315789473685
# C: 0.01
# G: 100
# ConfusionMatrix (sigmoid kernel) : [[ 0 34]
#  [ 0 42]]
# Accuracy (sigmoid kernel) : 0.5526315789473685
# C: 0.1
# G: 0.001
# ConfusionMatrix (sigmoid kernel) : [[ 7 27]
#  [ 2 40]]
# Accuracy (sigmoid kernel) : 0.618421052631579
# C: 0.1
# G: 0.01
# ConfusionMatrix (sigmoid kernel) : [[ 0 34]
#  [ 0 42]]
# Accuracy (sigmoid kernel) : 0.5526315789473685
# C: 0.1
# G: 0.1
# ConfusionMatrix (sigmoid kernel) : [[ 0 34]
#  [ 0 42]]
# Accuracy (sigmoid kernel) : 0.5526315789473685
# C: 0.1
# G: 1
# ConfusionMatrix (sigmoid kernel) : [[ 0 34]
#  [ 0 42]]
# Accuracy (sigmoid kernel) : 0.5526315789473685
# C: 0.1
# G: 10
# ConfusionMatrix (sigmoid kernel) : [[ 0 34]
#  [ 0 42]]
# Accuracy (sigmoid kernel) : 0.5526315789473685
# C: 0.1
# G: 100
# ConfusionMatrix (sigmoid kernel) : [[ 0 34]
#  [ 0 42]]
# Accuracy (sigmoid kernel) : 0.5526315789473685
# C: 1
# G: 0.001
# ConfusionMatrix (sigmoid kernel) : [[19 15]
#  [12 30]]
# Accuracy (sigmoid kernel) : 0.6447368421052632
# C: 1
# G: 0.01
# ConfusionMatrix (sigmoid kernel) : [[11 23]
#  [ 5 37]]
# Accuracy (sigmoid kernel) : 0.631578947368421
# C: 1
# G: 0.1
# ConfusionMatrix (sigmoid kernel) : [[ 0 34]
#  [ 0 42]]
# Accuracy (sigmoid kernel) : 0.5526315789473685
# C: 1
# G: 1
# ConfusionMatrix (sigmoid kernel) : [[ 0 34]
#  [ 0 42]]
# Accuracy (sigmoid kernel) : 0.5526315789473685
# C: 1
# G: 10
# ConfusionMatrix (sigmoid kernel) : [[ 0 34]
#  [ 0 42]]
# Accuracy (sigmoid kernel) : 0.5526315789473685
# C: 1
# G: 100
# ConfusionMatrix (sigmoid kernel) : [[ 0 34]
#  [ 0 42]]
# Accuracy (sigmoid kernel) : 0.5526315789473685
# C: 10
# G: 0.001
# ConfusionMatrix (sigmoid kernel) : [[21 13]
#  [12 30]]
# Accuracy (sigmoid kernel) : 0.6710526315789473
# C: 10
# G: 0.01
# ConfusionMatrix (sigmoid kernel) : [[14 20]
#  [ 7 35]]
# Accuracy (sigmoid kernel) : 0.6447368421052632
# C: 10
# G: 0.1
# ConfusionMatrix (sigmoid kernel) : [[ 1 33]
#  [ 0 42]]
# Accuracy (sigmoid kernel) : 0.5657894736842105
# C: 10
# G: 1
# ConfusionMatrix (sigmoid kernel) : [[ 0 34]
#  [ 0 42]]
# Accuracy (sigmoid kernel) : 0.5526315789473685
# C: 10
# G: 10
# ConfusionMatrix (sigmoid kernel) : [[ 0 34]
#  [ 0 42]]
# Accuracy (sigmoid kernel) : 0.5526315789473685
# C: 10
# G: 100
# ConfusionMatrix (sigmoid kernel) : [[ 0 34]
#  [ 0 42]]
# Accuracy (sigmoid kernel) : 0.5526315789473685
# C: 100
# G: 0.001
# ConfusionMatrix (sigmoid kernel) : [[22 12]
#  [16 26]]
# Accuracy (sigmoid kernel) : 0.631578947368421
# C: 100
# G: 0.01
# ConfusionMatrix (sigmoid kernel) : [[14 20]
#  [ 7 35]]
# Accuracy (sigmoid kernel) : 0.6447368421052632
# C: 100
# G: 0.1
# ConfusionMatrix (sigmoid kernel) : [[ 1 33]
#  [ 0 42]]
# Accuracy (sigmoid kernel) : 0.5657894736842105
# C: 100
# G: 1
# ConfusionMatrix (sigmoid kernel) : [[ 0 34]
#  [ 0 42]]
# Accuracy (sigmoid kernel) : 0.5526315789473685
# C: 100
# G: 10
# ConfusionMatrix (sigmoid kernel) : [[ 0 34]
#  [ 0 42]]
# Accuracy (sigmoid kernel) : 0.5526315789473685
# C: 100
# G: 100
# ConfusionMatrix (sigmoid kernel) : [[ 0 34]
#  [ 0 42]]
# Accuracy (sigmoid kernel) : 0.5526315789473685
# C: 1000
# G: 0.001
# ConfusionMatrix (sigmoid kernel) : [[20 14]
#  [ 9 33]]
# Accuracy (sigmoid kernel) : 0.6973684210526315
# C: 1000
# G: 0.01
# ConfusionMatrix (sigmoid kernel) : [[14 20]
#  [ 7 35]]
# Accuracy (sigmoid kernel) : 0.6447368421052632
# C: 1000
# G: 0.1
# ConfusionMatrix (sigmoid kernel) : [[ 1 33]
#  [ 0 42]]
# Accuracy (sigmoid kernel) : 0.5657894736842105
# C: 1000
# G: 1
# ConfusionMatrix (sigmoid kernel) : [[ 0 34]
#  [ 0 42]]
# Accuracy (sigmoid kernel) : 0.5526315789473685
# C: 1000
# G: 10
# ConfusionMatrix (sigmoid kernel) : [[ 0 34]
#  [ 0 42]]
# Accuracy (sigmoid kernel) : 0.5526315789473685
# C: 1000
# G: 100
# ConfusionMatrix (sigmoid kernel) : [[ 0 34]
#  [ 0 42]]
# Accuracy (sigmoid kernel) : 0.5526315789473685
